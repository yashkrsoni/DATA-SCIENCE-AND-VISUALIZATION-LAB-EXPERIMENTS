# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes_dataset00.csv')

# %%
df.head()
# Out:
#                              Target Genetic Markers Autoantibodies  \
# 0          Steroid-Induced Diabetes        Positive       Negative
# 1  Neonatal Diabetes Mellitus (NDM)        Positive       Negative
# 2                       Prediabetic        Positive       Positive
# 3                   Type 1 Diabetes        Negative       Positive
# 4                  Wolfram Syndrome        Negative       Negative
#
#   Family History Environmental Factors  Insulin Levels  Age  BMI  \
# 0             No               Present              40   44   38
# 1             No               Present              13    1   17
# 2            Yes               Present              27   36   24
# 3             No               Present               8    7   16
# 4            Yes               Present              17   10   17
#
#   Physical Activity Dietary Habits  ...  Pulmonary Function  \
# 0              High        Healthy  ...                76.0
# ...

# %%
df.head(10)
# Out:
#                              Target Genetic Markers Autoantibodies  \
# 0          Steroid-Induced Diabetes        Positive       Negative
# 1  Neonatal Diabetes Mellitus (NDM)        Positive       Negative
# 2                       Prediabetic        Positive       Positive
# 3                   Type 1 Diabetes        Negative       Positive
# 4                  Wolfram Syndrome        Negative       Negative
# 5                              LADA        Positive       Negative
# 6                   Type 2 Diabetes        Negative       Negative
# 7         Wolcott-Rallison Syndrome        Positive       Negative
# 8                Secondary Diabetes        Negative       Positive
# 9                Secondary Diabetes        Positive       Negative
#
#   Family History Environmental Factors  Insulin Levels  Age  BMI  \
# 0             No               Present              40   44   38
# 1             No               Present              13    1   17
# ...

# %%
df.head(100)
# Out:
#                               Target Genetic Markers Autoantibodies  \
# 0           Steroid-Induced Diabetes        Positive       Negative
# 1   Neonatal Diabetes Mellitus (NDM)        Positive       Negative
# 2                        Prediabetic        Positive       Positive
# 3                    Type 1 Diabetes        Negative       Positive
# 4                   Wolfram Syndrome        Negative       Negative
# ..                               ...             ...            ...
# 95  Neonatal Diabetes Mellitus (NDM)        Positive       Positive
# 96                              MODY        Negative       Negative
# 97          Steroid-Induced Diabetes        Positive       Negative
# 98                   Type 1 Diabetes        Negative       Positive
# 99         Wolcott-Rallison Syndrome        Negative       Negative
#
#    Family History Environmental Factors  Insulin Levels  Age  BMI  \
# 0              No               Present              40   44   38
# ...

# %%
df.tail()
# Out:
#                                            Target Genetic Markers  \
# 10269  Type 3c Diabetes (Pancreatogenic Diabetes)        Positive
# 10270                             Type 2 Diabetes        Negative
# 10271            Neonatal Diabetes Mellitus (NDM)        Positive
# 10272                   Wolcott-Rallison Syndrome        Negative
# 10273            Neonatal Diabetes Mellitus (NDM)        Negative
#
#       Autoantibodies Family History Environmental Factors  Insulin Levels  \
# 10269       Negative             No                Absent              28
# 10270       Positive             No               Present              32
# 10271       Negative             No                Absent               7
# 10272       Negative            Yes                Absent               7
# 10273       Negative            Yes               Present               8
#
#        Age  BMI Physical Activity Dietary Habits  ...  Pulmonary Function  \
# ...

# %%
df.tail(10)
# Out:
#                                            Target Genetic Markers  \
# 10264                             Type 2 Diabetes        Negative
# 10265                    Steroid-Induced Diabetes        Negative
# 10266     Cystic Fibrosis-Related Diabetes (CFRD)        Negative
# 10267                        Gestational Diabetes        Negative
# 10268                          Secondary Diabetes        Positive
# 10269  Type 3c Diabetes (Pancreatogenic Diabetes)        Positive
# 10270                             Type 2 Diabetes        Negative
# 10271            Neonatal Diabetes Mellitus (NDM)        Positive
# 10272                   Wolcott-Rallison Syndrome        Negative
# 10273            Neonatal Diabetes Mellitus (NDM)        Negative
#
#       Autoantibodies Family History Environmental Factors  Insulin Levels  \
# 10264       Negative            Yes               Present              32
# 10265       Negative             No                Absent              19
# ...

# %%
df.tail(100)
# Out:
#                                            Target Genetic Markers  \
# 10174                            Wolfram Syndrome        Negative
# 10175                                        MODY        Negative
# 10176  Type 3c Diabetes (Pancreatogenic Diabetes)        Positive
# 10177                                 Prediabetic        Negative
# 10178                             Type 2 Diabetes        Negative
# ...                                           ...             ...
# 10269  Type 3c Diabetes (Pancreatogenic Diabetes)        Positive
# 10270                             Type 2 Diabetes        Negative
# 10271            Neonatal Diabetes Mellitus (NDM)        Positive
# 10272                   Wolcott-Rallison Syndrome        Negative
# 10273            Neonatal Diabetes Mellitus (NDM)        Negative
#
#       Autoantibodies Family History Environmental Factors  Insulin Levels  \
# 10174       Negative            Yes               Present              10
# ...

# %%
df.shape
# Out:
# (10274, 34)

# %%
df.columns
# Out:
# Index(['Target', 'Genetic Markers', 'Autoantibodies', 'Family History',
#        'Environmental Factors', 'Insulin Levels', 'Age', 'BMI',
#        'Physical Activity', 'Dietary Habits', 'Blood Pressure',
#        'Cholesterol Levels', 'Waist Circumference', 'Blood Glucose Levels',
#        'Ethnicity', 'Socioeconomic Factors', 'Smoking Status',
#        'Alcohol Consumption', 'Glucose Tolerance Test', 'History of PCOS',
#        'Previous Gestational Diabetes', 'Pregnancy History',
#        'Weight Gain During Pregnancy', 'Pancreatic Health',
#        'Pulmonary Function', 'Cystic Fibrosis Diagnosis',
#        'Steroid Use History', 'Genetic Testing', 'Neurological Assessments',
#        'Liver Function Tests', 'Digestive Enzyme Levels', 'Urine Test',
#        'Birth Weight', 'Early Onset Symptoms'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Target                            object
# Genetic Markers                   object
# Autoantibodies                    object
# Family History                    object
# Environmental Factors             object
# Insulin Levels                     int64
# Age                                int64
# BMI                                int64
# Physical Activity                 object
# Dietary Habits                    object
# Blood Pressure                   float64
# Cholesterol Levels               float64
# Waist Circumference              float64
# Blood Glucose Levels             float64
# Ethnicity                         object
# Socioeconomic Factors             object
# Smoking Status                    object
# Alcohol Consumption               object
# Glucose Tolerance Test            object
# History of PCOS                   object
# Previous Gestational Diabetes     object
# Pregnancy History                 object
# Weight Gain During Pregnancy     float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10274 entries, 0 to 10273
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Target                         10274 non-null  object
#  1   Genetic Markers                10274 non-null  object
#  2   Autoantibodies                 10274 non-null  object
#  3   Family History                 10274 non-null  object
#  4   Environmental Factors          10274 non-null  object
#  5   Insulin Levels                 10274 non-null  int64
#  6   Age                            10274 non-null  int64
#  7   BMI                            10274 non-null  int64
#  8   Physical Activity              10274 non-null  object
#  9   Dietary Habits                 10273 non-null  object
#  10  Blood Pressure                 10273 non-null  float64
#  11  Cholesterol Levels             10273 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Insulin Levels           Age           BMI  Blood Pressure  \
# count    10274.000000  10274.000000  10274.000000    10273.000000
# mean        21.708390     32.124684     24.840179      111.590772
# std         10.880833     20.906222      6.040790       19.859391
# min          5.000000      0.000000     12.000000       60.000000
# 25%         13.000000     14.000000     20.000000      100.000000
# 50%         19.000000     31.000000     25.000000      113.000000
# 75%         28.000000     49.000000     29.000000      125.000000
# max         49.000000     79.000000     39.000000      149.000000
#
#        Cholesterol Levels  Waist Circumference  Blood Glucose Levels  \
# count        10273.000000         10273.000000          10273.000000
# mean           195.191083            35.082254            160.716928
# std             44.555017             6.825480             48.128676
# min            100.000000            20.000000             80.000000
# ...

# %% [markdown]
# **CHECK DATA QUALITY**

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Target                           0
# Genetic Markers                  0
# Autoantibodies                   0
# Family History                   0
# Environmental Factors            0
# Insulin Levels                   0
# Age                              0
# BMI                              0
# Physical Activity                0
# Dietary Habits                   1
# Blood Pressure                   1
# Cholesterol Levels               1
# Waist Circumference              1
# Blood Glucose Levels             1
# Ethnicity                        1
# Socioeconomic Factors            1
# Smoking Status                   1
# Alcohol Consumption              1
# Glucose Tolerance Test           1
# History of PCOS                  1
# Previous Gestational Diabetes    1
# Pregnancy History                1
# Weight Gain During Pregnancy     1
# Pancreatic Health                1
# Pulmonary Function               1
# Cystic Fibrosis Diagnosis        1
# Steroid Use History              1
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Target                             13
# Genetic Markers                     2
# Autoantibodies                      2
# Family History                      2
# Environmental Factors               2
# Insulin Levels                     45
# Age                                80
# BMI                                28
# Physical Activity                   4
# Dietary Habits                      2
# Blood Pressure                     90
# Cholesterol Levels                200
# Waist Circumference                35
# Blood Glucose Levels              220
# Ethnicity                           2
# Socioeconomic Factors               3
# Smoking Status                      2
# Alcohol Consumption                 3
# Glucose Tolerance Test              2
# History of PCOS                     2
# Previous Gestational Diabetes       2
# Pregnancy History                   2
# Weight Gain During Pregnancy       40
# Pancreatic Health                  90
# Pulmonary Function                 60
# ...

# %%
df['Age'].unique()
# Out:
# array([44,  1, 36,  7, 10, 41, 30,  3, 47, 72, 67, 29, 59,  0, 45, 53, 60,
#        16, 35, 14, 64,  9, 65, 34, 51, 11, 56, 37, 22, 70, 33, 50, 62, 40,
#        28, 12, 38, 19, 39, 46, 43, 77, 73, 32,  5, 49, 26, 52, 21, 54, 18,
#        42, 31, 23, 58, 13,  8, 48, 55, 17, 24, 25, 79,  6,  2,  4, 69, 27,
#        15, 61, 20, 66, 68, 78, 57, 71, 63, 75, 74, 76])

# %%
df['Insulin Levels'].unique()
# Out:
# array([40, 13, 27,  8, 17, 29, 10, 47, 21, 16, 22,  9, 38, 14, 12, 30, 19,
#        42, 34, 11, 24, 44, 20, 15, 18,  6, 28, 48,  5, 46, 26, 45, 33, 23,
#        41, 39,  7, 31, 35, 25, 32, 36, 43, 49, 37])

# %%
df['BMI'].unique()
# Out:
# array([38, 17, 24, 16, 26, 31, 18, 25, 29, 23, 28, 19, 22, 37, 32, 33, 39,
#        34, 15, 21, 27, 35, 14, 20, 12, 13, 30, 36])

# %%
df['Birth Weight'].unique()
# Out:
# array([2629., 1881., 3622., ..., 4001., 1625.,   nan])

# %%
df['Blood Glucose Levels'].unique()
# Out:
# array([168., 178., 105., 121., 289., 142., 186., 206., 160., 192., 114.,
#        113., 175., 136., 200., 132., 190., 126.,  93., 167., 234., 161.,
#        287., 170., 198., 146., 156., 137., 131., 129., 255., 108., 181.,
#        106., 248., 166., 172., 103., 133., 115., 245., 127., 111., 150.,
#        112., 223., 219., 120., 188., 239., 123., 221., 240., 185., 154.,
#         97., 233., 201., 148., 163., 138., 153., 157., 152., 145., 212.,
#        164., 122., 191., 104., 195., 130.,  96., 244., 100., 102., 159.,
#        118., 238., 197., 290., 236., 128., 216., 242., 209., 246.,  84.,
#        265., 124., 109.,  92., 125., 158.,  94., 237., 232., 107., 203.,
#        250., 135., 140., 173., 184., 227., 174., 171., 183., 182., 211.,
#        169., 189., 207.,  83., 155.,  95., 116., 101.,  99., 251.,  90.,
#        187., 144., 176., 241., 213., 165., 249., 143., 205., 243., 162.,
#        199., 273., 274.,  98., 266., 139., 149., 231., 222., 151., 220.,
# ...

# %%
# Check how many zero in Blood Glucose Levels
(df['Blood Glucose Levels']==0).sum()
# Out:
# np.int64(0)

# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes_dataset00.csv')

# %%
# Check how many zero in whole dataset
df.isin([0]).sum()
# Out:
# Target                              0
# Genetic Markers                     0
# Autoantibodies                      0
# Family History                      0
# Environmental Factors               0
# Insulin Levels                      0
# Age                              2655
# BMI                                 0
# Physical Activity                   0
# Dietary Habits                      0
# Blood Pressure                      0
# Cholesterol Levels                  0
# Waist Circumference                 0
# Blood Glucose Levels                0
# Ethnicity                           0
# Socioeconomic Factors               0
# Smoking Status                      0
# Alcohol Consumption                 0
# Glucose Tolerance Test              0
# History of PCOS                     0
# Previous Gestational Diabetes       0
# Pregnancy History                   0
# Weight Gain During Pregnancy     2731
# Pancreatic Health                   0
# Pulmonary Function                  0
# ...

# %%
# selecting single column
df['BMI']
# Out:
# 0        38
# 1        17
# 2        24
# 3        16
# 4        17
#          ..
# 69995    35
# 69996    31
# 69997    15
# 69998    24
# 69999    28
# Name: BMI, Length: 70000, dtype: int64

# %%
(df[['Birth Weight','Blood Pressure','Insulin Levels','Blood Glucose Levels','BMI']]==0).sum()
# Out:
# Birth Weight            0
# Blood Pressure          0
# Insulin Levels          0
# Blood Glucose Levels    0
# BMI                     0
# dtype: int64

# %%
# Selecting multiple columns
df[['Blood Glucose Levels','BMI','Age']]
# Out:
#        Blood Glucose Levels  BMI  Age
# 0                       168   38   44
# 1                       178   17    1
# 2                       105   24   36
# 3                       121   16    7
# 4                       289   17   10
# ...                     ...  ...  ...
# 69995                   227   35   38
# 69996                   149   31   51
# 69997                   143   15   11
# 69998                   126   24   30
# 69999                   117   28   41
#
# [70000 rows x 3 columns]

# %%
# Filter row with single condition
df[df['Age']>50]
# Out:
#                                            Target Genetic Markers  \
# 9                              Secondary Diabetes        Positive
# 10                             Secondary Diabetes        Negative
# 12                                    Prediabetic        Positive
# 15                       Steroid-Induced Diabetes        Positive
# 18     Type 3c Diabetes (Pancreatogenic Diabetes)        Positive
# ...                                           ...             ...
# 69978  Type 3c Diabetes (Pancreatogenic Diabetes)        Positive
# 69986                          Secondary Diabetes        Negative
# 69988                          Secondary Diabetes        Negative
# 69993                    Steroid-Induced Diabetes        Positive
# 69996                                        LADA        Positive
#
#       Autoantibodies Family History Environmental Factors  Insulin Levels  \
# 9           Negative            Yes               Present              21
# ...

# %%
df[df['BMI']>50]
# Out:
# Empty DataFrame
# Columns: [Target, Genetic Markers, Autoantibodies, Family History, Environmental Factors, Insulin Levels, Age, BMI, Physical Activity, Dietary Habits, Blood Pressure, Cholesterol Levels, Waist Circumference, Blood Glucose Levels, Ethnicity, Socioeconomic Factors, Smoking Status, Alcohol Consumption, Glucose Tolerance Test, History of PCOS, Previous Gestational Diabetes, Pregnancy History, Weight Gain During Pregnancy, Pancreatic Health, Pulmonary Function, Cystic Fibrosis Diagnosis, Steroid Use History, Genetic Testing, Neurological Assessments, Liver Function Tests, Digestive Enzyme Levels, Urine Test, Birth Weight, Early Onset Symptoms]
# Index: []
#
# [0 rows x 34 columns]

# %%
# Filter rows with multiple conditions
df[(df['Age']>50) & (df['BMI']>50)]
# Out:
# Empty DataFrame
# Columns: [Target, Genetic Markers, Autoantibodies, Family History, Environmental Factors, Insulin Levels, Age, BMI, Physical Activity, Dietary Habits, Blood Pressure, Cholesterol Levels, Waist Circumference, Blood Glucose Levels, Ethnicity, Socioeconomic Factors, Smoking Status, Alcohol Consumption, Glucose Tolerance Test, History of PCOS, Previous Gestational Diabetes, Pregnancy History, Weight Gain During Pregnancy, Pancreatic Health, Pulmonary Function, Cystic Fibrosis Diagnosis, Steroid Use History, Genetic Testing, Neurological Assessments, Liver Function Tests, Digestive Enzyme Levels, Urine Test, Birth Weight, Early Onset Symptoms]
# Index: []
#
# [0 rows x 34 columns]

# %%
df[(df['Age']>50) & (df['Blood Glucose Levels']>50)]
# Out:
#                                            Target Genetic Markers  \
# 9                              Secondary Diabetes        Positive
# 10                             Secondary Diabetes        Negative
# 12                                    Prediabetic        Positive
# 15                       Steroid-Induced Diabetes        Positive
# 18     Type 3c Diabetes (Pancreatogenic Diabetes)        Positive
# ...                                           ...             ...
# 69978  Type 3c Diabetes (Pancreatogenic Diabetes)        Positive
# 69986                          Secondary Diabetes        Negative
# 69988                          Secondary Diabetes        Negative
# 69993                    Steroid-Induced Diabetes        Positive
# 69996                                        LADA        Positive
#
#       Autoantibodies Family History Environmental Factors  Insulin Levels  \
# 9           Negative            Yes               Present              21
# ...

# %%
# Access rows by index(iloc)
df.iloc[10:15]
# Out:
#                               Target Genetic Markers Autoantibodies  \
# 10                Secondary Diabetes        Negative       Positive
# 11                   Type 1 Diabetes        Positive       Negative
# 12                       Prediabetic        Positive       Negative
# 13  Neonatal Diabetes Mellitus (NDM)        Positive       Positive
# 14                              LADA        Negative       Negative
#
#    Family History Environmental Factors  Insulin Levels  Age  BMI  \
# 10             No               Present              16   67   29
# 11             No                Absent               8   29   23
# 12             No                Absent              22   59   28
# 13             No               Present               9    0   19
# 14             No                Absent              21   45   22
#
#    Physical Activity Dietary Habits  ...  Pulmonary Function  \
# 10               Low        Healthy  ...                  75
# ...

# %%
df.iloc[30:40]
# Out:
#                               Target Genetic Markers Autoantibodies  \
# 30          Steroid-Induced Diabetes        Negative       Negative
# 31  Neonatal Diabetes Mellitus (NDM)        Positive       Negative
# 32                   Type 2 Diabetes        Positive       Positive
# 33              Gestational Diabetes        Negative       Positive
# 34                  Wolfram Syndrome        Positive       Negative
# 35                              LADA        Positive       Negative
# 36                   Type 1 Diabetes        Positive       Negative
# 37              Gestational Diabetes        Negative       Positive
# 38                   Type 2 Diabetes        Positive       Positive
# 39              Gestational Diabetes        Negative       Negative
#
#    Family History Environmental Factors  Insulin Levels  Age  BMI  \
# 30            Yes                Absent              44   51   34
# 31             No               Present              11    0   18
# ...

# %% [markdown]
# **SORTING AND GROUPING**

# %%
df.sort_values(by='Age',ascending=True).head()
# Out:
#                                  Target Genetic Markers Autoantibodies  \
# 17212  Neonatal Diabetes Mellitus (NDM)        Negative       Negative
# 20781  Neonatal Diabetes Mellitus (NDM)        Negative       Negative
# 36740  Neonatal Diabetes Mellitus (NDM)        Positive       Positive
# 52769  Neonatal Diabetes Mellitus (NDM)        Positive       Positive
# 36761  Neonatal Diabetes Mellitus (NDM)        Negative       Negative
#
#       Family History Environmental Factors  Insulin Levels  Age  BMI  \
# 17212            Yes                Absent               6    0   14
# 20781             No                Absent               9    0   13
# 36740            Yes               Present              14    0   13
# 52769             No               Present               5    0   15
# 36761            Yes                Absent               5    0   19
#
#       Physical Activity Dietary Habits  ...  Pulmonary Function  \
# ...

# %%
df.sort_values(by='Age',ascending=True).tail()
# Out:
#                    Target Genetic Markers Autoantibodies Family History  \
# 32573  Secondary Diabetes        Positive       Positive            Yes
# 43799     Type 2 Diabetes        Negative       Positive             No
# 15261  Secondary Diabetes        Negative       Negative             No
# 15181  Secondary Diabetes        Positive       Negative             No
# 15194  Secondary Diabetes        Positive       Negative            Yes
#
#       Environmental Factors  Insulin Levels  Age  BMI Physical Activity  \
# 32573               Present              42   79   28              High
# 43799               Present              47   79   38          Moderate
# 15261                Absent              12   79   30              High
# 15181               Present              31   79   31               Low
# 15194                Absent              37   79   33          Moderate
#
#       Dietary Habits  ...  Pulmonary Function  Cystic Fibrosis Diagnosis  \
# ...

# %%
df['BMI'].value_counts()
# Out:
# BMI
# 24    4864
# 27    4184
# 26    4146
# 25    4080
# 28    4016
# 22    3804
# 23    3796
# 20    3426
# 21    3357
# 18    3100
# 19    3075
# 29    3034
# 32    2658
# 30    2650
# 34    2626
# 33    2626
# 31    2592
# 17    2313
# 16    2277
# 15    2256
# 12     693
# 14     692
# 13     667
# 38     638
# 36     612
# 35     611
# 37     609
# 39     598
# Name: count, dtype: int64

# %% [markdown]
# **GROUP BY AND AGGREGATE**

# %%
df.groupby('BMI').mean(numeric_only=True)
# Out:
#      Insulin Levels        Age  Blood Pressure  Cholesterol Levels  \
# BMI
# 12         9.427128   0.503608       69.873016          149.414141
# 13         9.556222   0.464768       69.250375          148.377811
# 14         9.504335   0.554913       69.226879          149.144509
# 15        11.847961   8.344415       88.876330          150.331117
# 16        12.067633   8.967062       89.818182          151.499780
# 17        11.754431   8.608301       88.974492          151.351059
# 18        14.324839  12.207742       94.296452          157.807097
# 19        14.440000  12.017886       93.979837          158.399350
# 20        18.276708  22.690601      105.790718          175.177758
# 21        18.193327  22.552875      106.017277          175.675603
# 22        19.667455  26.475289      108.297056          182.615668
# 23        19.569810  26.872761      108.670706          183.085616
# 24        19.538651  30.588199      110.835938          187.707648
# ...

# %%
df['BMI'].mean()
# Out:
# np.float64(24.782942857142856)

# %%
df['Age'].mean()
# Out:
# np.float64(32.0207)

# %%
age_mode = df['Age'].mode()[0]
age_mode
# Out:
# np.int64(1)

# %%
mode_count = (df['Age']== age_mode).sum()

# %%
mode_count
# Out:
# np.int64(3165)

# %%
df['Age'].std()
# Out:
# 21.043173246867614

# %%
df['BMI'].std()
# Out:
# 6.014235736748566

# %%
df.corr(numeric_only=True)
# Out:
#                               Insulin Levels       Age       BMI  \
# Insulin Levels                      1.000000  0.608128  0.534044
# Age                                 0.608128  1.000000  0.662997
# BMI                                 0.534044  0.662997  1.000000
# Blood Pressure                      0.581814  0.763398  0.654009
# Cholesterol Levels                  0.551892  0.730426  0.603086
# Waist Circumference                 0.580608  0.733633  0.620750
# Blood Glucose Levels                0.102301  0.027659 -0.047480
# Weight Gain During Pregnancy        0.510186  0.698480  0.588552
# Pancreatic Health                   0.295518  0.444710  0.386623
# Pulmonary Function                  0.123034  0.261972  0.233309
# Neurological Assessments            0.411620  0.482672  0.372847
# Digestive Enzyme Levels             0.398418  0.581695  0.523032
# Birth Weight                        0.396347  0.523554  0.476306
#
# ...
